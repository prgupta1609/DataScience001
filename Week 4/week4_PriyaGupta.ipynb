# %% [markdown]
# # 📘 CIFAR-10 Image Classification Learning Project
# ## Build and Compare **ANN vs CNN** on CIFAR-10
#
# This notebook is designed as a practical learning project for CIFAR-10 image classification. I used the given notebook structure and completed the training experiments for:
# - ANN baseline
# - CNN model
# - CNN with training strategy upgrade using data augmentation
#
# 🎯 **Learning Goal:** Understand how model architecture and training strategy affect image classification performance.

# %% [markdown]
# # 🧠 Problem Statement
# Build an image classification model on the **CIFAR-10 dataset** using:
#
# 1. **Artificial Neural Network (ANN)**
# 2. **Convolutional Neural Network (CNN)**
#
# Then compare:
# - Accuracy
# - Loss curves
# - Generalization
# - Training strategies like dropout, batch normalization, early stopping, and augmentation
#
# ---
# ### 📦 CIFAR-10 Classes
# Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# # 📥 Load Dataset
# We use **CIFAR-10**, which contains **60,000 color images of size 32×32×3**.
# - 50,000 training images
# - 10,000 test images

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# c:\Users\Aradhya Gupta\Desktop\DataScience001\.venv\Lib\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %% [markdown]
# ## 🖼️ Visualize Sample Images

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🧹 Preprocessing
# We normalize pixel values from **0–255 → 0–1** so training becomes stable.

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

x_train_flat = x_train_norm.reshape(len(x_train_norm), -1)
x_test_flat = x_test_norm.reshape(len(x_test_norm), -1)

# %% [markdown]
# # 🔹 Part 1: ANN Model
# ANN treats images as **flat vectors**, so it cannot preserve spatial features.
#
# For this experiment, I increased the ANN depth to check whether adding more dense layers helps. This is useful as a baseline, but it still does not understand local image patterns like edges, corners, or textures.

# %%
ann_model = models.Sequential([
    layers.Dense(1024, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop_ann = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

ann_history = ann_model.fit(
    x_train_flat, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=128,
    callbacks=[early_stop_ann]
)
# Out:
# c:\Users\Aradhya Gupta\Desktop\DataScience001\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 83ms/step - accuracy: 0.2547 - loss: 2.0315 - val_accuracy: 0.3208 - val_loss: 1.8671
# Epoch 2/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.3239 - loss: 1.8610 - val_accuracy: 0.3570 - val_loss: 1.7832
# Epoch 3/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 31s 87ms/step - accuracy: 0.3432 - loss: 1.8031 - val_accuracy: 0.3792 - val_loss: 1.7556
# Epoch 4/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 81ms/step - accuracy: 0.3597 - loss: 1.7674 - val_accuracy: 0.3952 - val_loss: 1.7072
# Epoch 5/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 22s 63ms/step - accuracy: 0.3624 - loss: 1.7498 - val_accuracy: 0.3910 - val_loss: 1.6869
# Epoch 6/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 26s 73ms/step - accuracy: 0.3716 - loss: 1.7245 - val_accuracy: 0.4086 - val_loss: 1.6570
# Epoch 7/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.3806 - loss: 1.7033 - val_accuracy: 0.4058 - val_loss: 1.6673
# Epoch 8/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.3840 - loss: 1.6948 - val_accuracy: 0.4134 - val_loss: 1.6439
# Epoch 9/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.3930 - loss: 1.6740 - val_accuracy: 0.4304 - val_loss: 1.6070
# Epoch 10/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 30s 86ms/step - accuracy: 0.3999 - loss: 1.6568 - val_accuracy: 0.4234 - val_loss: 1.6183
# Epoch 11/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.4050 - loss: 1.6438 - val_accuracy: 0.4300 - val_loss: 1.6190
# Epoch 12/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 33s 94ms/step - accuracy: 0.4099 - loss: 1.6307 - val_accuracy: 0.4354 - val_loss: 1.5892
# Epoch 13/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 37s 105ms/step - accuracy: 0.4091 - loss: 1.6261 - val_accuracy: 0.4396 - val_loss: 1.5778
# Epoch 14/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.4127 - loss: 1.6187 - val_accuracy: 0.4528 - val_loss: 1.5863
# Epoch 15/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.4158 - loss: 1.6075 - val_accuracy: 0.4430 - val_loss: 1.5884
# Epoch 16/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.4186 - loss: 1.5972 - val_accuracy: 0.4530 - val_loss: 1.5892

# %%
ann_test_loss, ann_test_acc = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy:", ann_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.4452 - loss: 1.5645
# ANN Test Accuracy: 0.44519999623298645

# %% [markdown]
# # 🔹 Part 2: CNN Model
# CNN preserves **spatial relationships** using:
# - Convolution layers
# - Pooling
# - Feature extraction
# - Hierarchical learning
#
# Here I used filters in the pattern **32 → 64 → 128** so the model can learn simple visual patterns first and deeper features later. Batch normalization and dropout are added to make the training more stable and reduce overfitting.

# %%
cnn_model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop_cnn = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

cnn_history = cnn_model.fit(
    x_train_norm, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=128,
    callbacks=[early_stop_cnn]
)
# Out:
# c:\Users\Aradhya Gupta\Desktop\DataScience001\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 62s 147ms/step - accuracy: 0.4445 - loss: 1.5746 - val_accuracy: 0.1760 - val_loss: 3.5667
# Epoch 2/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 73s 122ms/step - accuracy: 0.5921 - loss: 1.1677 - val_accuracy: 0.5650 - val_loss: 1.2817
# Epoch 3/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 51s 144ms/step - accuracy: 0.6428 - loss: 1.0196 - val_accuracy: 0.5980 - val_loss: 1.1527
# Epoch 4/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 53s 150ms/step - accuracy: 0.6841 - loss: 0.9060 - val_accuracy: 0.6536 - val_loss: 0.9972
# Epoch 5/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 50s 142ms/step - accuracy: 0.7132 - loss: 0.8144 - val_accuracy: 0.6792 - val_loss: 0.9316
# Epoch 6/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 49s 140ms/step - accuracy: 0.7410 - loss: 0.7372 - val_accuracy: 0.6896 - val_loss: 0.9235
# Epoch 7/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 50s 141ms/step - accuracy: 0.7624 - loss: 0.6754 - val_accuracy: 0.6772 - val_loss: 1.0203
# Epoch 8/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 82s 142ms/step - accuracy: 0.7816 - loss: 0.6174 - val_accuracy: 0.6862 - val_loss: 0.9517
# Epoch 9/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 50s 142ms/step - accuracy: 0.7974 - loss: 0.5719 - val_accuracy: 0.6784 - val_loss: 0.9647

# %%
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy:", cnn_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6811 - loss: 0.9435
# CNN Test Accuracy: 0.6811000108718872

# %% [markdown]
# ## 📈 Compare Learning Curves

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN vs CNN Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 🚀 Training Strategy Upgrade: Data Augmentation
# This strategy improves generalization by generating transformed images.
#
# The idea is simple: instead of showing the model the exact same training images every time, I randomly flip, rotate, and zoom images a little. This helps the CNN learn more robust visual features instead of memorizing the training data.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

aug_cnn_model = models.Sequential([
    data_augmentation,

    layers.Conv2D(32, 3, activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Conv2D(128, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

aug_cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop_aug = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

aug_history = aug_cnn_model.fit(
    x_train_norm, y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=128,
    callbacks=[early_stop_aug]
)

aug_test_loss, aug_test_acc = aug_cnn_model.evaluate(x_test_norm, y_test)
print("Augmented CNN Test Accuracy:", aug_test_acc)
# Out:
# Epoch 1/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 65s 155ms/step - accuracy: 0.3792 - loss: 1.7401 - val_accuracy: 0.2730 - val_loss: 2.7955
# Epoch 2/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 54s 153ms/step - accuracy: 0.4907 - loss: 1.4261 - val_accuracy: 0.5622 - val_loss: 1.2313
# Epoch 3/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 84s 157ms/step - accuracy: 0.5280 - loss: 1.3235 - val_accuracy: 0.5114 - val_loss: 1.4172
# Epoch 4/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 54s 152ms/step - accuracy: 0.5648 - loss: 1.2328 - val_accuracy: 0.6376 - val_loss: 1.0315
# Epoch 5/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 56s 158ms/step - accuracy: 0.5866 - loss: 1.1749 - val_accuracy: 0.5866 - val_loss: 1.1391
# Epoch 6/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 81s 156ms/step - accuracy: 0.6061 - loss: 1.1277 - val_accuracy: 0.5638 - val_loss: 1.2983
# Epoch 7/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.6185 - loss: 1.0902 - val_accuracy: 0.6042 - val_loss: 1.1394
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6289 - loss: 1.0449
# Augmented CNN Test Accuracy: 0.6288999915122986

# %% [markdown]
# # 📊 Final Comparison Table

# %%
comparison = pd.DataFrame({
    "Model": ["ANN", "CNN", "CNN + Data Augmentation"],
    "Architecture / Strategy": [
        "Dense layers on flattened images",
        "Convolution filters 32→64→128 with BatchNorm and Dropout",
        "CNN with augmentation, BatchNorm, Dropout and EarlyStopping"
    ],
    "Test Accuracy": [ann_test_acc, cnn_test_acc, aug_test_acc]
})
comparison
# Out:
#                      Model                            Architecture / Strategy  \
# 0                      ANN                   Dense layers on flattened images
# 1                      CNN  Convolution filters 32→64→128 with BatchNorm a...
# 2  CNN + Data Augmentation  CNN with augmentation, BatchNorm, Dropout and ...
#
#    Test Accuracy
# 0         0.4452
# 1         0.6811
# 2         0.6289

# %% [markdown]
# # 🎓 Student Learning Tasks
# These tasks are covered in the completed notebook:
#
# ### ✅ Beginner Tasks
# 1. Increased ANN layers and observed performance
# 2. Changed CNN filters in the pattern 32→64→128
# 3. Increased training epochs to 20
# 4. Added **EarlyStopping**
# 5. Added **data augmentation training**

# %% [markdown]
# # ✅ Conclusion
# - **ANN works as a baseline**, but it flattens the image and ignores image structure.
# - **CNN performs better for images** because convolution layers extract spatial features like edges, colors, textures, and shapes.
# - Increasing CNN filters from **32 → 64 → 128** helps the model learn features from simple to complex levels.
# - Training strategies like **dropout, batch normalization, early stopping, and data augmentation** help improve generalization and reduce overfitting.
# - This project builds strong fundamentals for **computer vision interviews and deep learning projects**, because it clearly shows why CNNs are preferred over plain ANN models for image classification.
